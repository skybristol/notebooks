# %% [markdown]
# This notebook explores work in progress on a data processing workflow for data sources of spatial features of interest in our work on the National Biogeographic Map. The Spatial Feature Registry (or spatiotemporal once we get back to working through implications of time bounded features) is a part of the information system we are building to support work on the NBM. We need a steady process of integrating disparate datasets of spatial features of interest in our work and running a set of processors on the data to add value for our purposes.
#
# The code blocks and notes here share some ideas we are kicking around. They go along with an [ESIP Lab ideascale campaign](https://esipfed.ideascale.com/a/campaign-home/23576) and a [screencast presentation](https://youtu.be/J7T59-H_W4o).

# %%
import requests
from IPython.display import display

# %% [markdown]
# # Places API (an end result)
# We are trying to take an API-first approach to everything we build; first setting up routes in an API that abstracts from our back-end data infrastructure and establishes a set of methods and tools that get at data and functionality we are exposing. The BIS API (BIS is for Biogeographic Information System) is built as a Python Flask app using the RESTPlus package ([beta API](https://sciencebase.usgs.gov/staging/bis/)).
#
# The information you see in this result is just the output from an ElasticSearch query made against a set of indexes created for each registered data source. We need to do a little work in the API response to eliminate the cruft and show a result that is more abstracted from the underlying infrastructure that will stand the test of time. The part that we're concentrating on now is how to go about taking each individual data source we want to register (the registrants in the SFR) and document them such that we have everything on board the dataset we need to understand how to run our processing pipeline.

# %%
placesTextSearchResults = requests.get('https://sciencebase.usgs.gov/staging/bis/api/v1/places/search/text?q=Yosemite').json()

for result in placesTextSearchResults['hits']['hits']:
    display(result)
# Out:
# {'_id': '5296',
#  '_index': 'bis__sfr__published_doi_lands_from_padus_1_4',
#  '_score': 8.229219,
#  '_source': {'properties': {'feature_class': 'Wilderness Area',
#    'feature_description': '',
#    'feature_id': 'PADUS1_4:WA:Yosemite Wilderness',
#    'feature_name': 'Yosemite Wilderness',
#    'gid': 5296,
#    'ogc_fid': 5296,
#    'source_data': '[ { "access": "RA", "d_access": "Restricted Access", "access_src": "GAP - Default", "agg_src": "GAP_PADUS1_4Designation_NPS_Wilderness_20150605.gdb\\/LegislatedWilderness", "category": "Designation", "d_category": "Designation", "comments": "", "date_est": "1984", "gapcddt": "2014", "gapcdsrc": "Interagency Wilderness Steering Committee", "gap_sts": "1", "d_gap_sts": "1 - managed for biodiversity - disturbance events proceed or are mimicked", "gis_acres": 704358, "gis_src": "NPS_Wilderness_20150605.gdb\\/LegislatedWilderness", "iucnctdt": "2015", "iucnctsrc": "GAP - Default", "iucn_cat": "Ib", "d_iucn_cat": "Ib: Wilderness areas", "loc_ds": "Designated", "loc_mang": "National Park Service - YOSE", "loc_nm": "Yosemite Wilderness", "loc_own": "", "mang_name": "NPS", "d_mang_name": "National Park Service", "mang_type": "FED", "d_mang_typ": "Federal", "own_name": "DESG", "d_own_name": "Designation", "own_type": "DESG", "d_own_type": "Designation", "source_pai": "{7008DB95-E942-4B90-A167-6D0FB6914C13}", "state_nm": "CA", "d_state_nm": "California", "wdpa_cd": 1111193 } ]'}},
#  '_type': 'sfr__published_doi_lands_from_padus_1_4'}
# {'_id': '2054',
#  '_index': 'bis__sfr__published_doi_lands_from_padus_1_4',
#  '_score': 7.1782146,
#  '_source': {'properties': {'feature_class': 'National Park',
#    'feature_description': '',
#    'feature_id': 'PADUS1_4:NP:Yosemite National Park',
#    'feature_name': 'Yosemite National Park',
#    'gid': 2054,
#    'ogc_fid': 2054,
#    'source_data': '[ { "access": "OA", "d_access": "Open Access", "access_src": "GAP - Default", "agg_src": "GAP_PADUS1_4Fee_NPS_Tracts", "category": "Fee", "d_category": "Fee", "comments": "", "date_est": "1890", "gapcddt": "2010", "gapcdsrc": "TNC", "gap_sts": "1", "d_gap_sts": "1 - managed for biodiversity - disturbance events proceed or are mimicked", "gis_acres": 740655, "gis_src": "NPS_Tracts.shp", "iucnctdt": "2015", "iucnctsrc": "GAP - Default", "iucn_cat": "II", "d_iucn_cat": "II: National park", "loc_ds": "NP", "loc_mang": "FEDFEE", "loc_nm": "YOSE", "loc_own": "FEDFEE", "mang_name": "NPS", "d_mang_name": "National Park Service", "mang_type": "FED", "d_mang_typ": "Federal", "own_name": "NPS", "d_own_name": "National Park Service", "own_type": "FED", "d_own_type": "Federal", "source_pai": "880020-107", "state_nm": "CA", "d_state_nm": "California", "wdpa_cd": 975 }, { "access": "OA", "d_access": "Open Access", "access_src": "GAP - Default", "agg_src": "GAP_PADUS1_4Fee_NPS_Tracts", "category": "Fee", "d_category": "Fee", "comments": "", "date_est": "1890", "gapcddt": "2010", "gapcdsrc": "TNC", "gap_sts": "1", "d_gap_sts": "1 - managed for biodiversity - disturbance events proceed or are mimicked", "gis_acres": 926, "gis_src": "NPS_Tracts.shp", "iucnctdt": "2015", "iucnctsrc": "GAP - Default", "iucn_cat": "II", "d_iucn_cat": "II: National park", "loc_ds": "NP", "loc_mang": "FEDFEE-O", "loc_nm": "YOSE", "loc_own": "FEDFEE-O", "mang_name": "NPS", "d_mang_name": "National Park Service", "mang_type": "FED", "d_mang_typ": "Federal", "own_name": "NPS", "d_own_name": "National Park Service", "own_type": "FED", "d_own_type": "Federal", "source_pai": "880020-123", "state_nm": "CA", "d_state_nm": "California", "wdpa_cd": 975 }, { "access": "OA", "d_access": "Open Access", "access_src": "GAP - Default", "agg_src": "GAP_PADUS1_4Fee_NPS_Tracts", "category": "Other", "d_category": "Other", "comments": "", "date_est": "1890", "gapcddt": "2010", "gapcdsrc": "TNC", "gap_sts": "1", "d_gap_sts": "1 - managed for biodiversity - disturbance events proceed or are mimicked", "gis_acres": 172, "gis_src": "NPS_Tracts.shp", "iucnctdt": "2015", "iucnctsrc": "GAP - Default", "iucn_cat": "II", "d_iucn_cat": "II: National park", "loc_ds": "NP", "loc_mang": "FEDMIN", "loc_nm": "YOSE", "loc_own": "FEDMIN", "mang_name": "NPS", "d_mang_name": "National Park Service", "mang_type": "FED", "d_mang_typ": "Federal", "own_name": "UNK", "d_own_name": "Unknown", "own_type": "UNK", "d_own_type": "Unknown", "source_pai": "880020-128", "state_nm": "CA", "d_state_nm": "California", "wdpa_cd": 975 }, { "access": "OA", "d_access": "Open Access", "access_src": "GAP - Default", "agg_src": "GAP_PADUS1_4Fee_NPS_Tracts", "category": "Other", "d_category": "Other", "comments": "", "date_est": "1890", "gapcddt": "2010", "gapcdsrc": "TNC", "gap_sts": "1", "d_gap_sts": "1 - managed for biodiversity - disturbance events proceed or are mimicked", "gis_acres": 1041, "gis_src": "NPS_Tracts.shp", "iucnctdt": "2015", "iucnctsrc": "GAP - Default", "iucn_cat": "II", "d_iucn_cat": "II: National park", "loc_ds": "NP", "loc_mang": "FEDTIMBER", "loc_nm": "YOSE", "loc_own": "FEDTIMBER", "mang_name": "NPS", "d_mang_name": "National Park Service", "mang_type": "FED", "d_mang_typ": "Federal", "own_name": "UNK", "d_own_name": "Unknown", "own_type": "UNK", "d_own_type": "Unknown", "source_pai": "880021-125", "state_nm": "CA", "d_state_nm": "California", "wdpa_cd": 975 } ]'}},
#  '_type': 'sfr__published_doi_lands_from_padus_1_4'}

# %% [markdown]
# # Data Repository (the Registry)
# The Registry part of the SFR is really just a place to reposit everything we want to work with - sources of spatial features and their documentation. For our purposes, we are leveraging ScienceBase and a particular [collection](https://www.sciencebase.gov/catalog/item/55fafaf5e4b05d6c4e501b81) where we have the necessary permissions set up for registration items. ScienceBase gives us the following:
#
# * Flexible information model to store the basic elements of metadata we need to understand the source
# * API to program against
# * File repository to stash source files when needed, pre-processed files when appropriate, and additional documentation
#
# What ScienceBase doesn't give us at this time is an elegant versioning mechanism for either the items or the files. We can tell when an item changes or files are added/changed, but we don't have a versioning construct to work against with the current platform. We will have to cross that bridge soon with data sources that change through time, and we'll look at layering in some other mechanism to account for this dynamic.
#
# We have some further cleanup to do on some previous dumb ideas that did not stand the test of time, but the following listing shows the basic information we are concerned about in the registry.

# %%
sfrListing = requests.get('https://www.sciencebase.gov/catalog/items?parentId=55fafaf5e4b05d6c4e501b81&max=20&format=json&fields=title,summary,files,webLinks,dates,contacts').json()

display(sfrListing)
# Out:
# {'items': [{'contacts': [{'active': True,
#      'contactType': 'person',
#      'email': 'dwieferich@usgs.gov',
#      'firstName': 'Daniel',
#      'jobTitle': 'Physical Scientist',
#      'lastName': 'Wieferich',
#      'middleName': 'J',
#      'name': 'Daniel J Wieferich',
#      'oldPartyId': 66431,
#      'orcId': '0000-0003-1554-7992',
#      'organization': {'displayText': 'Biogeographic Characterization'},
#      'primaryLocation': {'building': 'DFC Bldg 810',
#       'buildingCode': 'KBT',
#       'faxPhone': '3032024710',
#       'mailAddress': {},
#       'name': 'CN=Daniel J Wieferich,OU=CSS,OU=Users,OU=OITS,OU=DI,DC=gs,DC=doi,DC=net - Primary Location',
#       'officePhone': '3032024603',
#       'streetAddress': {'city': 'Lakewood',
#        'line1': 'W 6th Ave Kipling St',
#        'state': 'CO',
#        'zip': '80225'}},
#      'type': 'Custodian'}],
#    'dates': [{'dateString': '2018-04-02',
#      'label': 'Creation',
#      'type': 'creation'},
#     {'dateString': '2016', 'label': 'Publication Date', 'type': 'Publication'},
#     {'dateString': '2018-04-02T10:16:22.639-06:00',
#      'label': 'Date Created',
#      'type': 'dateCreated'},
#     {'dateString': '2018-04-02T12:47:51.649-06:00',
#      'label': 'Last Updated',
#      'type': 'lastUpdated'}],
#    'files': [{'contentType': 'application/zip',
#      'dateUploaded': '2018-04-02T16:16:50.000Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/5ac25756e4b0e2c2dd0aa0f9?f=__disk__53%2Fdf%2F03%2F53df03d4cc0abfe474ce2035b4457e2b7e9e05cd',
#      'name': 'state_boundaries.zip',
#      'pathOnDisk': '__disk__53/df/03/53df03d4cc0abfe474ce2035b4457e2b7e9e05cd',
#      'size': 11537430,
#      'url': 'https://www.sciencebase.gov/catalog/file/get/5ac25756e4b0e2c2dd0aa0f9?f=__disk__53%2Fdf%2F03%2F53df03d4cc0abfe474ce2035b4457e2b7e9e05cd'}],
#    'id': '5ac25756e4b0e2c2dd0aa0f9',
#    'link': {'rel': 'self',
#     'url': 'https://www.sciencebase.gov/catalog/item/5ac25756e4b0e2c2dd0aa0f9'},
#    'relatedItems': {'link': {'rel': 'related',
#      'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5ac25756e4b0e2c2dd0aa0f9'}},
#    'summary': 'U.S. state boundary data registered into the spatial feature registry.  Source data are documented at https://www.sciencebase.gov/catalog/item/58259697e4b01fad86db263f.  These data equate to the referenced source data, but have two registration fields needed for the spatial feature registry.  Registration id (_id) is an identifier that is unique to the registry and registration source (reg_source) connects the registry to this ScienceBase item that documents the data in the registry.  We attempt to register data as-is into the registry, without altering geospatial or descriptive information.  In some cases we need to export and store data in a new file format to allow for registration.  These steps are documented in the X repository [...]',
#    'title': 'Spatial Feature Registration Files for U.S. State Boundaries',
#    'webLinks': [{'hidden': False,
#      'rel': 'related',
#      'title': 'source data documentation',
#      'type': 'webLink',
#      'typeLabel': 'Web Link',
#      'uri': 'https://www.sciencebase.gov/catalog/item/58259697e4b01fad86db263f'}]},
#   {'contacts': [{'contactType': 'organization',
#      'name': 'UNESCO-IODE-OBIS',
#      'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#      'type': 'Data Owner'},
#     {'contactType': 'person',
#      'name': 'Pieter Provoost',
#      'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#      'type': 'Data Owner'}],
#    'dates': [{'dateString': '2018-03-16',
#      'label': 'Validity Begins',
#      'type': 'validityBegins'},
#     {'dateString': '2018-03-16T08:50:13.127-06:00',
#      'label': 'Date Created',
#      'type': 'dateCreated'},
#     {'dateString': '2018-08-17T06:47:08.938-06:00',
#      'label': 'Last Updated',
#      'type': 'lastUpdated'}],
#    'files': [{'contentType': 'application/json',
#      'dateUploaded': '2018-03-16T15:21:00.000Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/5aabd9a5e4b081f61aaf009b?f=__disk__0b%2F36%2F8d%2F0b368d467464f385ee5eb187ee86ec5de9d6559f',
#      'name': 'OBIS Areas Code List.json',
#      'originalMetadata': False,
#      'pathOnDisk': '__disk__0b/36/8d/0b368d467464f385ee5eb187ee86ec5de9d6559f',
#      'processed': False,
#      'size': 264,
#      'title': 'codelist',
#      'url': 'https://www.sciencebase.gov/catalog/file/get/5aabd9a5e4b081f61aaf009b?f=__disk__0b%2F36%2F8d%2F0b368d467464f385ee5eb187ee86ec5de9d6559f',
#      'useForPreview': False},
#     {'contentType': 'application/zip',
#      'dateUploaded': '2018-08-17T12:44:49.000Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/5aabd9a5e4b081f61aaf009b?f=__disk__7f%2F56%2F07%2F7f560781844b1d51ac05b1e10bf6cf792ff18d7e',
#      'name': 'OBISAreas.zip',
#      'originalMetadata': False,
#      'pathOnDisk': '__disk__7f/56/07/7f560781844b1d51ac05b1e10bf6cf792ff18d7e',
#      'processed': False,
#      'size': 17292233,
#      'title': 'load file',
#      'url': 'https://www.sciencebase.gov/catalog/file/get/5aabd9a5e4b081f61aaf009b?f=__disk__7f%2F56%2F07%2F7f560781844b1d51ac05b1e10bf6cf792ff18d7e',
#      'useForPreview': False}],
#    'id': '5aabd9a5e4b081f61aaf009b',
#    'link': {'rel': 'self',
#     'url': 'https://www.sciencebase.gov/catalog/item/5aabd9a5e4b081f61aaf009b'},
#    'relatedItems': {'link': {'rel': 'related',
#      'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5aabd9a5e4b081f61aaf009b'}},
#    'summary': 'The UNESCO-IODE-OBIS Office assembles and maintains a set of marine areas for summarizing and reporting on biodiversity and biogeographic characterization metrics. We register these areas in the Spatial Feature Registry for use in our own work and ties into the OBIS API. The spatial features in this dataset originate from MarineRegions.org and other sources and have been minimally processed spatially for use.',
#    'title': 'Ocean Biogeographic Information System Areas',
#    'webLinks': [{'hidden': False,
#      'rel': 'service',
#      'title': 'OBIS Areas Names and Identifiers',
#      'type': 'serviceLink',
#      'typeLabel': 'Service Link',
#      'uri': 'http://api.iobis.org/area'},
#     {'hidden': False,
#      'rel': 'service',
#      'title': 'OBIS Geoserver WFS',
#      'type': 'serviceCapabilitiesUrl',
#      'typeLabel': 'OGC Service Capabilities URL',
#      'uri': 'http://iobis.org/geoserver/OBIS/ows?service=WFS&version=1.0.0&request=GetCapabilities'},
#     {'hidden': False,
#      'rel': 'related',
#      'title': 'Processing logic',
#      'type': 'sourceCode',
#      'typeLabel': 'Source Code',
#      'uri': 'https://github.com/usgs-bis/sfr/blob/master/OBIS%20Areas.ipynb'}]},
#   {'contacts': [{'active': True,
#      'contactType': 'person',
#      'email': 'dwieferich@usgs.gov',
#      'firstName': 'Daniel',
#      'jobTitle': 'Physical Scientist',
#      'lastName': 'Wieferich',
#      'middleName': 'J',
#      'name': 'Daniel J Wieferich',
#      'oldPartyId': 66431,
#      'orcId': '0000-0003-1554-7992',
#      'organization': {'displayText': 'Biogeographic Characterization'},
#      'primaryLocation': {'building': 'DFC Bldg 810',
#       'buildingCode': 'KBT',
#       'faxPhone': '3032024710',
#       'mailAddress': {},
#       'name': 'CN=Daniel J Wieferich,OU=CSS,OU=Users,OU=OITS,OU=DI,DC=gs,DC=doi,DC=net - Primary Location',
#       'officePhone': '3032024603',
#       'streetAddress': {'city': 'Lakewood',
#        'line1': 'W 6th Ave Kipling St',
#        'state': 'CO',
#        'zip': '80225'}},
#      'type': 'Custodian'}],
#    'dates': [{'dateString': '2018-04-02',
#      'label': 'Creation',
#      'type': 'creation'},
#     {'dateString': '2018-04-02T12:13:41.892-06:00',
#      'label': 'Date Created',
#      'type': 'dateCreated'},
#     {'dateString': '2018-04-02T12:39:07.732-06:00',
#      'label': 'Last Updated',
#      'type': 'lastUpdated'}],
#    'files': [{'contentType': 'application/zip',
#      'dateUploaded': '2018-04-02T18:39:07.728Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/5ac272d5e4b0e2c2dd0aa3e7?f=__disk__32%2F76%2F65%2F3276652648ba0e8aec9a410747a61fef9a4ed0b8',
#      'name': 'padus1_4.zip',
#      'pathOnDisk': '__disk__32/76/65/3276652648ba0e8aec9a410747a61fef9a4ed0b8',
#      'size': 935501532,
#      'url': 'https://www.sciencebase.gov/catalog/file/get/5ac272d5e4b0e2c2dd0aa3e7?f=__disk__32%2F76%2F65%2F3276652648ba0e8aec9a410747a61fef9a4ed0b8'}],
#    'id': '5ac272d5e4b0e2c2dd0aa3e7',
#    'link': {'rel': 'self',
#     'url': 'https://www.sciencebase.gov/catalog/item/5ac272d5e4b0e2c2dd0aa3e7'},
#    'relatedItems': {'link': {'rel': 'related',
#      'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5ac272d5e4b0e2c2dd0aa3e7'}},
#    'summary': 'Protected Areas Database of the United States (PAD-US) data registered into the spatial feature registry.  Source data are documented at https://www.sciencebase.gov/catalog/item/56bba648e4b08d617f657960.',
#    'title': 'Spatial Feature Registration Files for PAD-US',
#    'webLinks': [{'hidden': False,
#      'rel': 'related',
#      'title': 'source data documentation',
#      'type': 'webLink',
#      'typeLabel': 'Web Link',
#      'uri': 'https://www.sciencebase.gov/catalog/item/56bba648e4b08d617f657960'}]},
#   {'contacts': [{'contactType': 'person',
#      'firstName': 'James',
#      'lastName': 'Omernik',
#      'name': 'James Omernik',
#      'oldPartyId': 7713,
#      'organization': {'displayText': 'Geographic Science Team, EROS'},
#      'primaryLocation': {'building': 'Mundt Federal Building',
#       'buildingCode': 'KMN',
#       'mailAddress': {'city': 'Sioux Falls',
#        'country': 'USA',
#        'line1': '47914 252nd Street',
#        'state': 'SD',
#        'zip': '57198-9801'},
#       'name': 'James Omernik/GEOG/NOAC/USGS/DOI - Primary Location',
#       'officePhone': '6055946111',
#       'streetAddress': {'city': 'Sioux Falls',
#        'country': 'USA',
#        'line1': '47914 252nd Street',
#        'state': 'SD',
#        'zip': '57198-9801'}},
#      'type': 'Principal Investigator'},
#     {'active': True,
#      'contactType': 'person',
#      'email': 'gallant@usgs.gov',
#      'firstName': 'Alisa',
#      'lastName': 'Gallant',
#      'middleName': 'L',
#      'name': 'Alisa L Gallant',
#      'oldPartyId': 3510,
#      'orcId': '0000-0002-3029-6637',
#      'organization': {'displayText': 'Geographic Science Team, EROS'},
#      'primaryLocation': {'building': 'EROS - Mundt Federal Building',
#       'buildingCode': 'KMN',
#       'faxPhone': '6055946529',
#       'mailAddress': {'city': 'Sioux Falls',
#        'country': 'USA',
#        'line1': '47914 252nd Street',
#        'state': 'SD',
#        'zip': '57198-9801'},
#       'name': 'Alisa L Gallant/GEOG/USGS/DOI - Primary Location',
#       'officePhone': '6055942696',
#       'streetAddress': {'city': 'Sioux Falls',
#        'line1': '47914 252Nd Street',
#        'state': 'SD',
#        'zip': '57198'}},
#      'type': 'Principal Investigator'}],
#    'dates': [{'dateString': '2015-08-09T10:27:39.160-06:00',
#      'label': 'Date Created',
#      'type': 'dateCreated'},
#     {'dateString': '2018-08-23T15:07:33.205-06:00',
#      'label': 'Last Updated',
#      'type': 'lastUpdated'}],
#    'files': [{'contentType': 'application/zip',
#      'dateUploaded': '2015-08-09T18:30:02.000Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/55c77f7be4b08400b1fd82d4?f=__disk__e8%2Fb5%2Fc7%2Fe8b5c7ac8039efa8ef959f4a640ad32dab7b20c7',
#      'name': 'us_eco_l3_merged_features.zip',
#      'originalMetadata': False,
#      'pathOnDisk': '__disk__e8/b5/c7/e8b5c7ac8039efa8ef959f4a640ad32dab7b20c7',
#      'processed': False,
#      'size': 28452985,
#      'title': 'Zipped Shapefile with CONUS Level 3 Ecoregions',
#      'url': 'https://www.sciencebase.gov/catalog/file/get/55c77f7be4b08400b1fd82d4?f=__disk__e8%2Fb5%2Fc7%2Fe8b5c7ac8039efa8ef959f4a640ad32dab7b20c7',
#      'useForPreview': False},
#     {'contentType': 'application/zip',
#      'dateUploaded': '2015-08-09T18:26:47.000Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/55c77f7be4b08400b1fd82d4?f=__disk__dc%2F27%2Fbf%2Fdc27bf9ce36f682ef42c4a719cdf991119b174b6',
#      'name': 'ak_eco_l3_merged_features.zip',
#      'originalMetadata': False,
#      'pathOnDisk': '__disk__dc/27/bf/dc27bf9ce36f682ef42c4a719cdf991119b174b6',
#      'processed': False,
#      'size': 1760106,
#      'title': 'Zipped Shapefile with Alaska Level 3 Ecoregions',
#      'url': 'https://www.sciencebase.gov/catalog/file/get/55c77f7be4b08400b1fd82d4?f=__disk__dc%2F27%2Fbf%2Fdc27bf9ce36f682ef42c4a719cdf991119b174b6',
#      'useForPreview': False},
#     {'contentType': 'application/zip',
#      'dateUploaded': '2015-08-09T18:28:31.000Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/55c77f7be4b08400b1fd82d4?f=__disk__42%2Fce%2Faf%2F42ceaf78d86dd167c2e0e622aa41e17a757e46e1',
#      'name': 'us_eco_l3_merged_features.gdb.zip',
#      'originalMetadata': False,
#      'pathOnDisk': '__disk__42/ce/af/42ceaf78d86dd167c2e0e622aa41e17a757e46e1',
#      'processed': False,
#      'size': 15208419,
#      'title': 'Zipped file GDB with CONUS Level 3 Ecoregions',
#      'url': 'https://www.sciencebase.gov/catalog/file/get/55c77f7be4b08400b1fd82d4?f=__disk__42%2Fce%2Faf%2F42ceaf78d86dd167c2e0e622aa41e17a757e46e1',
#      'useForPreview': False},
#     {'contentType': 'application/zip',
#      'dateUploaded': '2015-08-09T18:26:38.000Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/55c77f7be4b08400b1fd82d4?f=__disk__ad%2Fc6%2F4e%2Fadc64e049aea2a9254e2746c9c4763803ba19020',
#      'name': 'ak_eco_l3_merged_features.gdb.zip',
#      'originalMetadata': False,
#      'pathOnDisk': '__disk__ad/c6/4e/adc64e049aea2a9254e2746c9c4763803ba19020',
#      'processed': False,
#      'size': 1018058,
#      'title': 'Zipped file GDB with Alaska Level 3 Ecoregions',
#      'url': 'https://www.sciencebase.gov/catalog/file/get/55c77f7be4b08400b1fd82d4?f=__disk__ad%2Fc6%2F4e%2Fadc64e049aea2a9254e2746c9c4763803ba19020',
#      'useForPreview': False},
#     {'checksum': {'type': 'MD5', 'value': '870feee8b62114e8044f411970ecb123'},
#      'contentType': 'text/plain',
#      'dateUploaded': '2017-12-19T22:20:56.000Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/55c77f7be4b08400b1fd82d4?f=__disk__e9%2F84%2Fbd%2Fe984bd8b5198655d285811d641a5b6f1b4c17cc2',
#      'name': 'Eco_Level_3_descriptions.txt',
#      'originalMetadata': False,
#      'pathOnDisk': '__disk__e9/84/bd/e984bd8b5198655d285811d641a5b6f1b4c17cc2',
#      'processed': False,
#      'size': 74685,
#      'title': 'Descriptions of Ecoregions as Tab Delimited Text File',
#      'url': 'https://www.sciencebase.gov/catalog/file/get/55c77f7be4b08400b1fd82d4?f=__disk__e9%2F84%2Fbd%2Fe984bd8b5198655d285811d641a5b6f1b4c17cc2',
#      'useForPreview': False,
#      'viewUri': 'https://www.sciencebase.gov/catalog/file/get/55c77f7be4b08400b1fd82d4?f=__disk__e9%2F84%2Fbd%2Fe984bd8b5198655d285811d641a5b6f1b4c17cc2&allowOpen=true'},
#     {'checksum': {'type': 'MD5', 'value': 'f02315e408fd712c460cbda5798dcb18'},
#      'contentType': 'application/zip',
#      'dateUploaded': '2017-12-19T22:26:23.000Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/55c77f7be4b08400b1fd82d4?f=__disk__dc%2F0e%2F59%2Fdc0e596a343c40453ec4d2ff0c4844ace87420a5',
#      'name': 'ak_eco_l3.zip',
#      'originalMetadata': False,
#      'pathOnDisk': '__disk__dc/0e/59/dc0e596a343c40453ec4d2ff0c4844ace87420a5',
#      'processed': False,
#      'size': 1796628,
#      'title': 'Unaltered Zipped Shapefile with Alaska Level 3 Ecoregions: Retrieved 20171219',
#      'url': 'https://www.sciencebase.gov/catalog/file/get/55c77f7be4b08400b1fd82d4?f=__disk__dc%2F0e%2F59%2Fdc0e596a343c40453ec4d2ff0c4844ace87420a5',
#      'useForPreview': False},
#     {'checksum': {'type': 'MD5', 'value': 'd24089511ae83f30fd301aebb7d07f12'},
#      'contentType': 'application/zip',
#      'dateUploaded': '2017-12-19T22:26:32.000Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/55c77f7be4b08400b1fd82d4?f=__disk__1c%2Fa5%2Fa3%2F1ca5a3acb3d73b2cba772c105407e5ff61526571',
#      'name': 'us_eco_l3.zip',
#      'originalMetadata': False,
#      'pathOnDisk': '__disk__1c/a5/a3/1ca5a3acb3d73b2cba772c105407e5ff61526571',
#      'processed': False,
#      'size': 28424315,
#      'title': 'Unaltered Zipped Shapefile with CONUS Level 3 Ecoregions: Retrieved 20171219',
#      'url': 'https://www.sciencebase.gov/catalog/file/get/55c77f7be4b08400b1fd82d4?f=__disk__1c%2Fa5%2Fa3%2F1ca5a3acb3d73b2cba772c105407e5ff61526571',
#      'useForPreview': False}],
#    'id': '55c77f7be4b08400b1fd82d4',
#    'link': {'rel': 'self',
#     'url': 'https://www.sciencebase.gov/catalog/item/55c77f7be4b08400b1fd82d4'},
#    'relatedItems': {'link': {'rel': 'related',
#      'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=55c77f7be4b08400b1fd82d4'}},
#    'summary': 'Ecoregions denote areas of general similarity in ecosystems and in the type, quality, and quantity of environmental resources. They are designed to serve as a spatial framework for the research, assessment, management, and monitoring of ecosystems and ecosystem components. These general purpose regions are critical for structuring and implementing ecosystem management strategies across federal agencies, state agencies, and nongovernment organizations that are responsible for different types of resources within the same geographical areas. The approach used to compile this map is based on the premise that ecological regions can be identified through the analysis of patterns of biotic and abiotic phenomena, including geology, physiography, [...]',
#    'title': 'Omernik Level III Ecoregions for the US (including Alaska) for use as a reference data collection',
#    'webLinks': [{'hidden': False,
#      'title': 'Level III Ecoregions of the Continental U.S.',
#      'type': 'webLink',
#      'typeLabel': 'Web Link',
#      'uri': 'https://www.epa.gov/eco-research/ecoregions'},
#     {'hidden': False,
#      'title': 'Level III Ecoregions of Alaska',
#      'type': 'webLink',
#      'typeLabel': 'Web Link',
#      'uri': 'http://www.epa.gov/wed/pages/ecoregions/ak_eco.htm'},
#     {'hidden': False,
#      'title': 'Descriptions of Ecoregions of CONUS and Alaska',
#      'type': 'webLink',
#      'typeLabel': 'Web Link',
#      'uri': 'ftp://ftp.epa.gov/wed/ecoregions/us/Eco_Level_III_descriptions.doc'},
#     {'hidden': False,
#      'title': 'CONUS Level III Ecoregions shapefile without state boundaries (used as source for this collection)',
#      'type': 'download',
#      'typeLabel': 'Download',
#      'uri': 'ftp://ftp.epa.gov/wed/ecoregions/us/us_eco_l3.zip'},
#     {'hidden': False,
#      'title': 'Alaska Level III Ecoregions shapefile (used as source for this collection)',
#      'type': 'download',
#      'typeLabel': 'Download',
#      'uri': 'ftp://ftp.epa.gov/wed/ecoregions/ak/ak_eco_l3.zip'}]},
#   {'contacts': [{'contactType': 'person',
#      'firstName': 'Kenneth',
#      'jobTitle': 'Director, U.S. LME Program',
#      'lastName': 'Sherman',
#      'name': 'Kenneth Sherman',
#      'organization': {'displayText': 'US Department of Commerce, National Oceanic and Atmospheric Administration, Northeast Fisheries Science Center, Narragansett Laboratory'},
#      'personalTitle': 'Dr.',
#      'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#      'type': 'Principal Investigator'},
#     {'contactType': 'person',
#      'firstName': 'Rebecca',
#      'jobTitle': 'Fishery Biologist / LME Program Manager',
#      'lastName': 'Shuford',
#      'middleName': 'L',
#      'name': 'Rebecca L. Shuford',
#      'organization': {'displayText': 'U.S. Department of Commerce, National Oceanographic and Atmospheric Administration, Fisheries Office of Science and Technology, Marine Ecosystems Division'},
#      'personalTitle': 'Dr.',
#      'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#      'type': 'Co-Investigator'},
#     {'contactType': 'person',
#      'firstName': 'Sally',
#      'jobTitle': 'Technical Editor',
#      'lastName': 'Adams',
#      'name': 'Sally Adams',
#      'organization': {'displayText': 'US Department of Commerce, National Oceanic and Atmospheric Administration, Northeast Fisheries Science Center, Narragansett Laboratory'},
#      'personalTitle': 'Dr.',
#      'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#      'type': 'Co-Investigator'},
#     {'contactType': 'person',
#      'firstName': 'Jennifer',
#      'jobTitle': 'Natural Resource Coordinator / LME Coordinator',
#      'lastName': 'Bosch',
#      'name': 'Jennifer Bosch',
#      'organization': {'displayText': 'U.S. Department of Commerce, National Oceanographic and Atmospheric Administration, Fisheries Office of Science and Technology, Marine Ecosystems Division'},
#      'personalTitle': 'Dr.',
#      'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#      'type': 'Co-Investigator'}],
#    'dates': [{'dateString': '2017-04',
#      'label': 'Last Revision',
#      'type': 'lastRevision'},
#     {'dateString': '2015-08-09T09:52:02.874-06:00',
#      'label': 'Date Created',
#      'type': 'dateCreated'},
#     {'dateString': '2018-10-10T10:35:27.530-06:00',
#      'label': 'Last Updated',
#      'type': 'lastUpdated'}],
#    'files': [{'checksum': {'type': 'MD5',
#       'value': '5badc7809d7c74d555136bc06bb29a6a'},
#      'contentType': 'application/zip',
#      'dateUploaded': '2017-12-20T20:19:15.000Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/55c77722e4b08400b1fd8244?f=__disk__bc%2F30%2Fa7%2Fbc30a756b8fa9f6f45586407c8aea502688cf6ab',
#      'name': 'LME66.zip',
#      'originalMetadata': False,
#      'pathOnDisk': '__disk__bc/30/a7/bc30a756b8fa9f6f45586407c8aea502688cf6ab',
#      'processed': False,
#      'size': 7259964,
#      'title': 'Cached Source Data',
#      'url': 'https://www.sciencebase.gov/catalog/file/get/55c77722e4b08400b1fd8244?f=__disk__bc%2F30%2Fa7%2Fbc30a756b8fa9f6f45586407c8aea502688cf6ab',
#      'useForPreview': False},
#     {'contentType': 'text/csv',
#      'dateUploaded': '2018-10-10T14:55:49.000Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/55c77722e4b08400b1fd8244?f=__disk__56%2F9a%2Ffa%2F569afadd82bb5552962912322fb4d564d6833487',
#      'name': 'lme_abstracts_briefs.csv',
#      'originalMetadata': False,
#      'pathOnDisk': '__disk__56/9a/fa/569afadd82bb5552962912322fb4d564d6833487',
#      'processed': False,
#      'size': 75586,
#      'title': 'LME Abstracts',
#      'url': 'https://www.sciencebase.gov/catalog/file/get/55c77722e4b08400b1fd8244?f=__disk__56%2F9a%2Ffa%2F569afadd82bb5552962912322fb4d564d6833487',
#      'useForPreview': False,
#      'viewUri': 'https://www.sciencebase.gov/catalog/file/get/55c77722e4b08400b1fd8244?f=__disk__56%2F9a%2Ffa%2F569afadd82bb5552962912322fb4d564d6833487&allowOpen=true'},
#     {'contentType': 'application/zip',
#      'dateUploaded': '2018-10-10T15:43:54.000Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/55c77722e4b08400b1fd8244?f=__disk__3c%2Fbd%2F36%2F3cbd36a7744c76f3b94e8880deef64114fa0d6c8',
#      'name': 'LMESourceDataPackage.zip',
#      'originalMetadata': False,
#      'pathOnDisk': '__disk__3c/bd/36/3cbd36a7744c76f3b94e8880deef64114fa0d6c8',
#      'processed': False,
#      'size': 9821116,
#      'title': 'Source Data Package',
#      'url': 'https://www.sciencebase.gov/catalog/file/get/55c77722e4b08400b1fd8244?f=__disk__3c%2Fbd%2F36%2F3cbd36a7744c76f3b94e8880deef64114fa0d6c8',
#      'useForPreview': False},
#     {'contentType': 'text/x-python',
#      'dateUploaded': '2018-10-10T15:43:42.000Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/55c77722e4b08400b1fd8244?f=__disk__2f%2F77%2F0f%2F2f770f25c2f15805403ca2455486cbecb9a7ea8a',
#      'name': 'lme_shp_to_json.py',
#      'originalMetadata': False,
#      'pathOnDisk': '__disk__2f/77/0f/2f770f25c2f15805403ca2455486cbecb9a7ea8a',
#      'processed': False,
#      'size': 4940,
#      'title': 'Pre-processing Script',
#      'url': 'https://www.sciencebase.gov/catalog/file/get/55c77722e4b08400b1fd8244?f=__disk__2f%2F77%2F0f%2F2f770f25c2f15805403ca2455486cbecb9a7ea8a',
#      'useForPreview': False}],
#    'id': '55c77722e4b08400b1fd8244',
#    'link': {'rel': 'self',
#     'url': 'https://www.sciencebase.gov/catalog/item/55c77722e4b08400b1fd8244'},
#    'relatedItems': {'link': {'rel': 'related',
#      'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=55c77722e4b08400b1fd8244'}},
#    'summary': 'Large Marine Ecosystems (LMEs) are relatively large areas of ocean space of approximately 200,000 sq km; or greater, adjacent to the continents in coastal waters where primary productivity is generally higher than in open ocean areas.',
#    'title': 'Large Marine Ecosystems',
#    'webLinks': [{'hidden': False,
#      'title': 'Large Marine Ecosystems Web Site',
#      'type': 'webLink',
#      'typeLabel': 'Web Link',
#      'uri': 'http://lme.edc.uri.edu/'},
#     {'hidden': False,
#      'title': 'LME Data Downloads',
#      'type': 'webLink',
#      'typeLabel': 'Web Link',
#      'uri': 'http://lme.edc.uri.edu/index.php?option=com_content&view=category&layout=blog&id=48&Itemid=268'},
#     {'hidden': False,
#      'title': 'Large Marine Ecosystems of the World',
#      'type': 'browseImage',
#      'typeLabel': 'Browse Image',
#      'uri': 'http://lme.edc.uri.edu/images/mapthumbs/lme64_poster.jpg'},
#     {'hidden': False,
#      'title': 'Zipped Shapefile of LME Boundaries',
#      'type': 'download',
#      'typeLabel': 'Download',
#      'uri': 'http://lme.edc.uri.edu/images/Content/Downloads/DigitalData/LME66.zip'}]},
#   {'contacts': [{'active': True,
#      'contactType': 'person',
#      'email': 'dwieferich@usgs.gov',
#      'firstName': 'Daniel',
#      'jobTitle': 'Physical Scientist',
#      'lastName': 'Wieferich',
#      'middleName': 'J',
#      'name': 'Daniel J Wieferich',
#      'oldPartyId': 66431,
#      'orcId': '0000-0003-1554-7992',
#      'organization': {'displayText': 'Biogeographic Characterization'},
#      'primaryLocation': {'building': 'DFC Bldg 810',
#       'buildingCode': 'KBT',
#       'faxPhone': '3032024710',
#       'mailAddress': {},
#       'name': 'CN=Daniel J Wieferich,OU=CSS,OU=Users,OU=OITS,OU=DI,DC=gs,DC=doi,DC=net - Primary Location',
#       'officePhone': '3032024603',
#       'streetAddress': {'city': 'Lakewood',
#        'line1': 'W 6th Ave Kipling St',
#        'state': 'CO',
#        'zip': '80225'}},
#      'type': 'Custodian'}],
#    'dates': [{'dateString': '2018-03-29',
#      'label': 'Creation',
#      'type': 'creation'},
#     {'dateString': '2011-11-29',
#      'label': 'Begin Position',
#      'type': 'beginPosition'},
#     {'dateString': '2011-11-29',
#      'label': 'End Position',
#      'type': 'endPosition'},
#     {'dateString': '2018-03-30T15:14:54.396-06:00',
#      'label': 'Date Created',
#      'type': 'dateCreated'},
#     {'dateString': '2018-04-02T14:52:05.123-06:00',
#      'label': 'Last Updated',
#      'type': 'lastUpdated'}],
#    'files': [{'contentType': 'application/zip',
#      'dateUploaded': '2018-03-30T21:16:08.000Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/5abea8cee4b081f61ac14e35?f=__disk__67%2F16%2F64%2F671664a7e04b8b2207cad33bbd2cdc0c98f4c0d3',
#      'name': 'canadian_territories_provinces.zip',
#      'pathOnDisk': '__disk__67/16/64/671664a7e04b8b2207cad33bbd2cdc0c98f4c0d3',
#      'size': 40813445,
#      'url': 'https://www.sciencebase.gov/catalog/file/get/5abea8cee4b081f61ac14e35?f=__disk__67%2F16%2F64%2F671664a7e04b8b2207cad33bbd2cdc0c98f4c0d3'}],
#    'id': '5abea8cee4b081f61ac14e35',
#    'link': {'rel': 'self',
#     'url': 'https://www.sciencebase.gov/catalog/item/5abea8cee4b081f61ac14e35'},
#    'relatedItems': {'link': {'rel': 'related',
#      'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5abea8cee4b081f61ac14e35'}},
#    'summary': "Canadian Provinces and Territories data registered into the spatial feature registry.  Source data are documented at https://www.sciencebase.gov/catalog/item/5ab555c6e4b081f61ab78093.  These data are representative of the referenced source data, but have two registration fields allowing for entry into the spatial feature registry.  A registration identifier, '_id', is an identifier that is unique to the registry and registration source, 'reg_source', connects the registry to this ScienceBase item that documents the data which describes the dataset that the feature was registered from.  We attempt to register data provided by the source, without altering geospatial or descriptive information.  In some cases we need to export and store [...]",
#    'title': 'Spatial Feature Registration Files for Canadian Provinces and Territories',
#    'webLinks': [{'hidden': False,
#      'rel': 'related',
#      'title': 'source data documentation',
#      'type': 'webLink',
#      'typeLabel': 'Web Link',
#      'uri': 'https://www.sciencebase.gov/catalog/item/5ab555c6e4b081f61ab78093'}]},
#   {'contacts': [{'active': True,
#      'contactType': 'person',
#      'email': 'dwieferich@usgs.gov',
#      'firstName': 'Daniel',
#      'jobTitle': 'Physical Scientist',
#      'lastName': 'Wieferich',
#      'middleName': 'J',
#      'name': 'Daniel J Wieferich',
#      'oldPartyId': 66431,
#      'orcId': '0000-0003-1554-7992',
#      'organization': {'displayText': 'Biogeographic Characterization'},
#      'primaryLocation': {'building': 'DFC Bldg 810',
#       'buildingCode': 'KBT',
#       'faxPhone': '3032024710',
#       'mailAddress': {},
#       'name': 'CN=Daniel J Wieferich,OU=CSS,OU=Users,OU=OITS,OU=DI,DC=gs,DC=doi,DC=net - Primary Location',
#       'officePhone': '3032024603',
#       'streetAddress': {'city': 'Lakewood',
#        'line1': 'W 6th Ave Kipling St',
#        'state': 'CO',
#        'zip': '80225'}},
#      'type': 'Custodian'}],
#    'dates': [{'dateString': '2018-04-06',
#      'label': 'Creation',
#      'type': 'creation'},
#     {'dateString': '2017', 'label': 'Begin Position', 'type': 'beginPosition'},
#     {'dateString': '2017', 'label': 'End Position', 'type': 'endPosition'},
#     {'dateString': '2018-04-06T10:06:38.379-06:00',
#      'label': 'Date Created',
#      'type': 'dateCreated'},
#     {'dateString': '2018-04-06T11:30:13.130-06:00',
#      'label': 'Last Updated',
#      'type': 'lastUpdated'}],
#    'files': [{'contentType': 'application/zip',
#      'dateUploaded': '2018-04-06T16:06:56.000Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/5ac79b0ee4b0e2c2dd1014d4?f=__disk__45%2Fea%2F7f%2F45ea7f89fc2647b6b07c4c92f05272879074173a',
#      'name': 'mexico_states.zip',
#      'pathOnDisk': '__disk__45/ea/7f/45ea7f89fc2647b6b07c4c92f05272879074173a',
#      'size': 10383132,
#      'url': 'https://www.sciencebase.gov/catalog/file/get/5ac79b0ee4b0e2c2dd1014d4?f=__disk__45%2Fea%2F7f%2F45ea7f89fc2647b6b07c4c92f05272879074173a'}],
#    'id': '5ac79b0ee4b0e2c2dd1014d4',
#    'link': {'rel': 'self',
#     'url': 'https://www.sciencebase.gov/catalog/item/5ac79b0ee4b0e2c2dd1014d4'},
#    'relatedItems': {'link': {'rel': 'related',
#      'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5ac79b0ee4b0e2c2dd1014d4'}},
#    'summary': "States of mexico data registered into the spatial feature registry.  Source data are documented at https://www.sciencebase.gov/catalog/item/5ab57393e4b081f61ab781f4.  These data are representative of the referenced source data, but have two registration fields allowing for entry into the spatial feature registry.  A registration identifier, '_id', is an identifier that is unique to the registry and registration source, 'reg_source', connects the registry to this ScienceBase item that documents the data which describes the dataset that the feature was registered from.  We attempt to register data provided by the source, without altering geospatial or descriptive information.  In some cases we need to export and store data in a new file [...]",
#    'title': 'Spatial Feature Registration Files for States of Mexico',
#    'webLinks': [{'hidden': False,
#      'rel': 'related',
#      'title': 'source data documentation',
#      'type': 'webLink',
#      'typeLabel': 'Web Link',
#      'uri': 'https://www.sciencebase.gov/catalog/item/5ab57393e4b081f61ab781f4'}]},
#   {'contacts': [{'active': True,
#      'contactType': 'person',
#      'email': 'dwieferich@usgs.gov',
#      'firstName': 'Daniel',
#      'jobTitle': 'Physical Scientist',
#      'lastName': 'Wieferich',
#      'middleName': 'J',
#      'name': 'Daniel J Wieferich',
#      'oldPartyId': 66431,
#      'orcId': '0000-0003-1554-7992',
#      'organization': {'displayText': 'Biogeographic Characterization'},
#      'primaryLocation': {'building': 'DFC Bldg 810',
#       'buildingCode': 'KBT',
#       'faxPhone': '3032024710',
#       'mailAddress': {},
#       'name': 'CN=Daniel J Wieferich,OU=CSS,OU=Users,OU=OITS,OU=DI,DC=gs,DC=doi,DC=net - Primary Location',
#       'officePhone': '3032024603',
#       'streetAddress': {'city': 'Lakewood',
#        'line1': 'W 6th Ave Kipling St',
#        'state': 'CO',
#        'zip': '80225'}},
#      'type': 'Contact'}],
#    'dates': [{'dateString': '2018-10-04T11:32:30.476-06:00',
#      'label': 'Date Created',
#      'type': 'dateCreated'},
#     {'dateString': '2018-10-04T11:39:01.987-06:00',
#      'label': 'Last Updated',
#      'type': 'lastUpdated'}],
#    'id': '5bb64eaee4b0fc368e893504',
#    'link': {'rel': 'self',
#     'url': 'https://www.sciencebase.gov/catalog/item/5bb64eaee4b0fc368e893504'},
#    'relatedItems': {'link': {'rel': 'related',
#      'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5bb64eaee4b0fc368e893504'}},
#    'summary': 'This collection contains records of removed dams. These items were created in ScienceBase during an earlier iteration of the Spatial Ferature Registry concept. As we are continuing to evolve the SFR, we are using the SFR collection to house not individual features but collections of features that are processed in different ways into larger indexes.',
#    'title': 'Removed Dams'},
#   {'dates': [{'dateString': '2018-04-13',
#      'label': 'Creation',
#      'type': 'creation'},
#     {'dateString': '2018-04-13T12:16:59.981-06:00',
#      'label': 'Date Created',
#      'type': 'dateCreated'},
#     {'dateString': '2018-04-13T12:55:26.525-06:00',
#      'label': 'Last Updated',
#      'type': 'lastUpdated'}],
#    'files': [{'contentType': 'application/zip',
#      'dateUploaded': '2018-04-13T18:55:26.522Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/5ad0f41be4b0e2c2dd1f58de?f=__disk__77%2F69%2F7c%2F77697c66b69683ea6c0554d64bc4a50c41e69bbb',
#      'name': 'ar_dam_removals.zip',
#      'pathOnDisk': '__disk__77/69/7c/77697c66b69683ea6c0554d64bc4a50c41e69bbb',
#      'size': 183103,
#      'url': 'https://www.sciencebase.gov/catalog/file/get/5ad0f41be4b0e2c2dd1f58de?f=__disk__77%2F69%2F7c%2F77697c66b69683ea6c0554d64bc4a50c41e69bbb'}],
#    'id': '5ad0f41be4b0e2c2dd1f58de',
#    'link': {'rel': 'self',
#     'url': 'https://www.sciencebase.gov/catalog/item/5ad0f41be4b0e2c2dd1f58de'},
#    'relatedItems': {'link': {'rel': 'related',
#      'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5ad0f41be4b0e2c2dd1f58de'}},
#    'title': 'Spatial Feature Registration Files for American Rivers Dam Removal Database',
#    'webLinks': [{'hidden': False,
#      'rel': 'related',
#      'title': 'source data documentation',
#      'type': 'webLink',
#      'typeLabel': 'Web Link',
#      'uri': 'https://www.sciencebase.gov/catalog/item/58259697e4b01fad86db263f'}]},
#   {'dates': [{'dateString': '2018-06-29',
#      'label': 'Creation',
#      'type': 'creation'},
#     {'dateString': '2018-06-01',
#      'label': 'Release Date',
#      'type': 'Release Date'},
#     {'dateString': '2018-06-29T12:12:33.981-06:00',
#      'label': 'Date Created',
#      'type': 'dateCreated'},
#     {'dateString': '2018-06-29T12:37:35.898-06:00',
#      'label': 'Last Updated',
#      'type': 'lastUpdated'}],
#    'files': [{'contentType': 'application/zip',
#      'dateUploaded': '2018-06-29T18:37:35.896Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/5b367691e4b040769c1754e7?f=__disk__d5%2F53%2F92%2Fd553927c960ec303d39f6291d280c2305f20823c',
#      'name': 'gnis_20180601.zip',
#      'pathOnDisk': '__disk__d5/53/92/d553927c960ec303d39f6291d280c2305f20823c',
#      'size': 195750841,
#      'url': 'https://www.sciencebase.gov/catalog/file/get/5b367691e4b040769c1754e7?f=__disk__d5%2F53%2F92%2Fd553927c960ec303d39f6291d280c2305f20823c'}],
#    'id': '5b367691e4b040769c1754e7',
#    'link': {'rel': 'self',
#     'url': 'https://www.sciencebase.gov/catalog/item/5b367691e4b040769c1754e7'},
#    'relatedItems': {'link': {'rel': 'related',
#      'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5b367691e4b040769c1754e7'}},
#    'summary': "GNIS Names data registered into the spatial feature registry. Source data are documented at https://geonames.usgs.gov'.",
#    'title': 'Spatial Feature Registration Files for GNIS Names (National File 2018-06-29) Database',
#    'webLinks': [{'hidden': False,
#      'rel': 'related',
#      'title': 'source data download',
#      'type': 'webLink',
#      'typeLabel': 'Web Link',
#      'uri': 'https://geonames.usgs.gov/docs/stategaz/NationalFile.zip'}]},
#   {'dates': [{'dateString': '2018-05-10',
#      'label': 'Creation',
#      'type': 'creation'},
#     {'dateString': '2018-05-10T16:22:08.389-06:00',
#      'label': 'Date Created',
#      'type': 'dateCreated'},
#     {'dateString': '2018-05-10T16:50:25.832-06:00',
#      'label': 'Last Updated',
#      'type': 'lastUpdated'}],
#    'files': [{'contentType': 'application/zip',
#      'dateUploaded': '2018-05-10T22:50:25.829Z',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/5af4c610e4b0da30c1b44f5f?f=__disk__38%2F72%2Fbf%2F3872bff32f09c2d0325986418db9ca98b192badc',
#      'name': 'drd_dam_removals.zip',
#      'pathOnDisk': '__disk__38/72/bf/3872bff32f09c2d0325986418db9ca98b192badc',
#      'size': 31831,
#      'url': 'https://www.sciencebase.gov/catalog/file/get/5af4c610e4b0da30c1b44f5f?f=__disk__38%2F72%2Fbf%2F3872bff32f09c2d0325986418db9ca98b192badc'}],
#    'id': '5af4c610e4b0da30c1b44f5f',
#    'link': {'rel': 'self',
#     'url': 'https://www.sciencebase.gov/catalog/item/5af4c610e4b0da30c1b44f5f'},
#    'relatedItems': {'link': {'rel': 'related',
#      'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5af4c610e4b0da30c1b44f5f'}},
#    'summary': 'Dam Removal Database v2.0 data registered into the spatial feature registry. Source data are documented at https://www.sciencebase.gov/catalog/item/5ace95e3e4b0e2c2dd1a688f.',
#    'title': 'Spatial Feature Registration Files for Dam Removal Database v2.0',
#    'webLinks': [{'hidden': False,
#      'rel': 'related',
#      'title': 'source data documentation',
#      'type': 'webLink',
#      'typeLabel': 'Web Link',
#      'uri': 'https://www.sciencebase.gov/catalog/item/5ace95e3e4b0e2c2dd1a688f'}]}],
#  'selflink': {'rel': 'self',
#   'url': 'https://www.sciencebase.gov/catalog/items?max=20&format=json&fields=title%2Csummary%2Cfiles%2CwebLinks%2Cdates%2Ccontacts&parentId=55fafaf5e4b05d6c4e501b81'},
#  'took': '141ms',
#  'total': 11}

# %% [markdown]
# # Data Source Documentation
# As you can see in the dump of information on registrants, we have quite a bit of cleanup and standardization still to do. We've worked through a number of ideas that have not quite scaled from generating individual ScienceBase Items to working through many different ways of packaging pre-processed data and linking to relevant code. As we work toward a production capability, we are seeking ways to simplify and clarify what we are doing in this mess.
#
# I'm currently working on setting a pattern for what we want to see in source material using the Large Marine Ecosystems registrant. That's listed here with some notes below on what we're doing in this case.

# %%
lme_item = next((i for i in sfrListing['items'] if i['title'] == 'Large Marine Ecosystems'), None)

display(lme_item)
# Out:
# {'contacts': [{'contactType': 'person',
#    'firstName': 'Kenneth',
#    'jobTitle': 'Director, U.S. LME Program',
#    'lastName': 'Sherman',
#    'name': 'Kenneth Sherman',
#    'organization': {'displayText': 'US Department of Commerce, National Oceanic and Atmospheric Administration, Northeast Fisheries Science Center, Narragansett Laboratory'},
#    'personalTitle': 'Dr.',
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Principal Investigator'},
#   {'contactType': 'person',
#    'firstName': 'Rebecca',
#    'jobTitle': 'Fishery Biologist / LME Program Manager',
#    'lastName': 'Shuford',
#    'middleName': 'L',
#    'name': 'Rebecca L. Shuford',
#    'organization': {'displayText': 'U.S. Department of Commerce, National Oceanographic and Atmospheric Administration, Fisheries Office of Science and Technology, Marine Ecosystems Division'},
#    'personalTitle': 'Dr.',
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Co-Investigator'},
#   {'contactType': 'person',
#    'firstName': 'Sally',
#    'jobTitle': 'Technical Editor',
#    'lastName': 'Adams',
#    'name': 'Sally Adams',
#    'organization': {'displayText': 'US Department of Commerce, National Oceanic and Atmospheric Administration, Northeast Fisheries Science Center, Narragansett Laboratory'},
#    'personalTitle': 'Dr.',
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Co-Investigator'},
#   {'contactType': 'person',
#    'firstName': 'Jennifer',
#    'jobTitle': 'Natural Resource Coordinator / LME Coordinator',
#    'lastName': 'Bosch',
#    'name': 'Jennifer Bosch',
#    'organization': {'displayText': 'U.S. Department of Commerce, National Oceanographic and Atmospheric Administration, Fisheries Office of Science and Technology, Marine Ecosystems Division'},
#    'personalTitle': 'Dr.',
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Co-Investigator'}],
#  'dates': [{'dateString': '2017-04',
#    'label': 'Last Revision',
#    'type': 'lastRevision'},
#   {'dateString': '2015-08-09T09:52:02.874-06:00',
#    'label': 'Date Created',
#    'type': 'dateCreated'},
#   {'dateString': '2018-10-10T10:35:27.530-06:00',
#    'label': 'Last Updated',
#    'type': 'lastUpdated'}],
#  'files': [{'checksum': {'type': 'MD5',
#     'value': '5badc7809d7c74d555136bc06bb29a6a'},
#    'contentType': 'application/zip',
#    'dateUploaded': '2017-12-20T20:19:15.000Z',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/55c77722e4b08400b1fd8244?f=__disk__bc%2F30%2Fa7%2Fbc30a756b8fa9f6f45586407c8aea502688cf6ab',
#    'name': 'LME66.zip',
#    'originalMetadata': False,
#    'pathOnDisk': '__disk__bc/30/a7/bc30a756b8fa9f6f45586407c8aea502688cf6ab',
#    'processed': False,
#    'size': 7259964,
#    'title': 'Cached Source Data',
#    'url': 'https://www.sciencebase.gov/catalog/file/get/55c77722e4b08400b1fd8244?f=__disk__bc%2F30%2Fa7%2Fbc30a756b8fa9f6f45586407c8aea502688cf6ab',
#    'useForPreview': False},
#   {'contentType': 'text/csv',
#    'dateUploaded': '2018-10-10T14:55:49.000Z',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/55c77722e4b08400b1fd8244?f=__disk__56%2F9a%2Ffa%2F569afadd82bb5552962912322fb4d564d6833487',
#    'name': 'lme_abstracts_briefs.csv',
#    'originalMetadata': False,
#    'pathOnDisk': '__disk__56/9a/fa/569afadd82bb5552962912322fb4d564d6833487',
#    'processed': False,
#    'size': 75586,
#    'title': 'LME Abstracts',
#    'url': 'https://www.sciencebase.gov/catalog/file/get/55c77722e4b08400b1fd8244?f=__disk__56%2F9a%2Ffa%2F569afadd82bb5552962912322fb4d564d6833487',
#    'useForPreview': False,
#    'viewUri': 'https://www.sciencebase.gov/catalog/file/get/55c77722e4b08400b1fd8244?f=__disk__56%2F9a%2Ffa%2F569afadd82bb5552962912322fb4d564d6833487&allowOpen=true'},
#   {'contentType': 'application/zip',
#    'dateUploaded': '2018-10-10T15:43:54.000Z',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/55c77722e4b08400b1fd8244?f=__disk__3c%2Fbd%2F36%2F3cbd36a7744c76f3b94e8880deef64114fa0d6c8',
#    'name': 'LMESourceDataPackage.zip',
#    'originalMetadata': False,
#    'pathOnDisk': '__disk__3c/bd/36/3cbd36a7744c76f3b94e8880deef64114fa0d6c8',
#    'processed': False,
#    'size': 9821116,
#    'title': 'Source Data Package',
#    'url': 'https://www.sciencebase.gov/catalog/file/get/55c77722e4b08400b1fd8244?f=__disk__3c%2Fbd%2F36%2F3cbd36a7744c76f3b94e8880deef64114fa0d6c8',
#    'useForPreview': False},
#   {'contentType': 'text/x-python',
#    'dateUploaded': '2018-10-10T15:43:42.000Z',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/55c77722e4b08400b1fd8244?f=__disk__2f%2F77%2F0f%2F2f770f25c2f15805403ca2455486cbecb9a7ea8a',
#    'name': 'lme_shp_to_json.py',
#    'originalMetadata': False,
#    'pathOnDisk': '__disk__2f/77/0f/2f770f25c2f15805403ca2455486cbecb9a7ea8a',
#    'processed': False,
#    'size': 4940,
#    'title': 'Pre-processing Script',
#    'url': 'https://www.sciencebase.gov/catalog/file/get/55c77722e4b08400b1fd8244?f=__disk__2f%2F77%2F0f%2F2f770f25c2f15805403ca2455486cbecb9a7ea8a',
#    'useForPreview': False}],
#  'id': '55c77722e4b08400b1fd8244',
#  'link': {'rel': 'self',
#   'url': 'https://www.sciencebase.gov/catalog/item/55c77722e4b08400b1fd8244'},
#  'relatedItems': {'link': {'rel': 'related',
#    'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=55c77722e4b08400b1fd8244'}},
#  'summary': 'Large Marine Ecosystems (LMEs) are relatively large areas of ocean space of approximately 200,000 sq km; or greater, adjacent to the continents in coastal waters where primary productivity is generally higher than in open ocean areas.',
#  'title': 'Large Marine Ecosystems',
#  'webLinks': [{'hidden': False,
#    'title': 'Large Marine Ecosystems Web Site',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'http://lme.edc.uri.edu/'},
#   {'hidden': False,
#    'title': 'LME Data Downloads',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'http://lme.edc.uri.edu/index.php?option=com_content&view=category&layout=blog&id=48&Itemid=268'},
#   {'hidden': False,
#    'title': 'Large Marine Ecosystems of the World',
#    'type': 'browseImage',
#    'typeLabel': 'Browse Image',
#    'uri': 'http://lme.edc.uri.edu/images/mapthumbs/lme64_poster.jpg'},
#   {'hidden': False,
#    'title': 'Zipped Shapefile of LME Boundaries',
#    'type': 'download',
#    'typeLabel': 'Download',
#    'uri': 'http://lme.edc.uri.edu/images/Content/Downloads/DigitalData/LME66.zip'}]}

# %% [markdown]
# The main things I'm working through are centered on files:
#
# * Pre-processing - For this item, I posted a rather clunky Python script that I used to do the pre-processing in this particular case. I did not spend the time working through how the functions should be abstracted to something higher level in our master Python package for all of this related work on the Biogeographic Information System. It's ugly, but it does at least show exactly what I did to the source data to set it up for our use and provides for the basic principles of transparency and reproducibility. It's also an example of what we will run into regularly when a given data source is really only going to be processed once with a purpose-built workflow.
# * Source Data Package - This package contains a final GeoJSON file for processing (results of the pre-processing script) and a first attempt at using [JSON Schema](https://json-schema.org/) to document the dataset with the most usable information for processing.
#
# For the schema documentation, I used a nifty [online tool](https://www.jsonschema.net/) with a snippet of the pre-processed GeoJSON file (generated with a function in the pre-processing script) to build a draft-07 compliant JSON schema file and then weaved in an idea for specifying a context for integration using really dumbed down JSON-LD notation. To support the mapping of source properties to a context for integration, I am fiddling with an ontology containing higher level properties and definitions [registered](http://cor.esipfed.org/ont/~sky/usgs_sfr) in the ESIP Community Ontology Repository. That gave me resolvable identities to map to in the following way:
#
# ```
# {
#   "@context": {
#     "@vocab": "http://cor.esipfed.org/ont/~sky/usgs_sfr",
#     "#/properties/features/items/properties/properties/properties/LME_NUMBER": "http://cor.esipfed.org/ont/usgs_sfr/integratingproperty/feature_id_sourceIdentifier",
#     "lme": "http://cor.esipfed.org/ont/usgs_sfr/integratingproperty/feature_id_nameSpaceId",
#     "Large Marine Ecosystems": "http://cor.esipfed.org/ont/usgs_sfr/integratingproperty/feature_class",
#     "#/properties/features/items/properties/properties/properties/LME_NAME": "http://cor.esipfed.org/ont/usgs_sfr/integratingproperty/feature_name",
#     "#/properties/features/items/properties/properties/properties/LME_DESCRIPTION": "http://cor.esipfed.org/ont/usgs_sfr/integratingproperty/feature_description"
#   }
# }
# ```
#
# You see the major concepts as properties here from the above API snippet. This mapping shows part of how to get from source data into the particular context of our one overarching indexing scheme (with the potential for multiple contexts in future). However, this probably isn't the best way to do things, and we're looking for better ideas.

# %% [markdown]
# # Message Queue and Microservices
# Our current workflow to get the SFR sources online involves another set of purpose built scripts and configuration details that pull the data from files into a PostGIS instance, build out materialized views that handle some geospatial cleanup and schema mapping, and then push the data into a set of similarly named ElasticSearch indexes for use in wildcard-based searches. That's an okay process but it's not very extensible, and it's a little hard for us to take it to full production right now. So, we are working on a new approach that will build from source items with documentation in ScienceBase and run the full pipeline using as much native Amazon tech as we can currently use.
#
# I'm thinking to leverage Amazon SQS with an initial message to check ScienceBase for processable stuff. The "find processable stuff" microservice can probably run as a Lambda. It will consult a config file with rules that look for specific characteristics of ScienceBase Items like having a "Source Data Package" and origination from a set of trusted users. It will look at a log of some kind to know whether a given item and its latest source data has already been processed. If conditions are met, it will put messages on the queue with items to process.
#
# "Process item" messages will trigger one or more microservices to load data and run it through our pipeline. We should look to see if we can chunk things up enough to run these as Lamdas as well, perhaps building in a safeguard as another message that would fire up the code on an actual machine to run if the Lambda time limit is exceeded in roundtripping a particular process.
